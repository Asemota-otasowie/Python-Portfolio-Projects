# %%
#import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
plt.rcParams['figure.figsize']=(12,8) # Adjust configuration of plots we create

#Read in data

df = pd.read_csv(r"C:\Users\OTAS\Desktop\movies.csv")
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Data cleaning process
#finding any missing data

for col in df.columns:
    missing_ratio=np.mean(df[col].isnull()) 
    print('{}-{}%'.format(col, missing_ratio))
# Out:
# name-0.0%
# rating-0.0%
# genre-0.0%
# year-0.0%
# released-0.0%
# score-0.0003912363067292645%
# votes-0.0003912363067292645%
# director-0.0%
# writer-0.0%
# star-0.0%
# country-0.0%
# budget-0.2831246739697444%
# gross-0.02464788732394366%
# company-0.0%
# runtime-0.0005216484089723526%

# %%
#Finding data types

df.dtypes
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score         int64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget        int64
# gross         int64
# company       int16
# runtime       int64
# dtype: object

# %%
#Changing float datatypes to integers

#df=df.apply(lambda x:
           # x.astype('int64') if x.dtype=='float64' else)  # Doesn't work because the dataset has some % of missing data

print(df[~np.isfinite(df[col])]) #identified columns with nan values, non-finite and finite
# Out:
#                         name rating   genre  year  \
# 5728  Saw: The Final Chapter      R   Crime  2010
# 5730             The Wolfman      R   Drama  2010
# 6195       One for the Money  PG-13  Action  2012
# 7665           Saving Mbango    NaN   Drama  2020
#
#                               released  score     votes             director  \
# 5728                               NaN    5.6   93000.0       Kevin Greutert
# 5730                               NaN    5.8  104000.0         Joe Johnston
# 6195  January 27, 2012 (United States)    5.3   41000.0  Julie Anne Robinson
# 7665         April 27, 2020 (Cameroon)    5.7      29.0         Nkanya Nkwai
#
#                    writer              star        country      budget  \
# 5728       Patrick Melton        Tobin Bell            NaN         NaN
# 5730  Andrew Kevin Walker  Benicio Del Toro            NaN         NaN
# 6195        Stacy Sherman   Katherine Heigl  United States  40000000.0
# ...

# %%
#Converting rows with non-finite values, finite and nan to placeholders(0, -1 etc)


df['budget']=df['budget'].fillna(0).astype('int64')
df['gross']=df['gross'].fillna(0).astype('int64')
df['score']=df['score'].fillna(0).astype('int64')
df['runtime']=df['runtime'].fillna(0).astype('int64')

# %%
# Now retry changing floats to integers
#df=df.apply(lambda x:
            #x.astype('int64') if x.dtype=='float64' else x) #it worked!!
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Creating correct year column
df['correct_year']=df['released'].str.extract(r'(\d{4})')
df=df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
# Finding and dropping duplicates
#pd.set_option('display.max_rows', None)

#df['company']=df['company'].drop_duplicates().sort_values(ascending=False)

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
#finding pearson correlaton between the budget and gross revenue

# %%
# scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title=('Budget vs Gross Earnings')
plt.xlabel('Budget')
plt.ylabel('Gross Earning')
plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Correlation using REG plot, using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"green"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson').head() #pearson #kendall #spearman
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
#
#              votes  director    writer      star   country    budget  \
# name      0.013088  0.009079  0.009081  0.006472 -0.010737  0.023970
# rating    0.033225  0.019483 -0.005921  0.013405  0.081244 -0.176002
# genre    -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.356564
# year      0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.329321
# released  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.014683
#
#              gross   company   runtime
# name      0.005533  0.009211  0.010392
# rating   -0.107339 -0.032943  0.062145
# ...

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title=('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Looking at company

df.sort_values(by=['gross'], ascending=False).head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0

# %%
#Changing data type to numeric value #category

df_numerized=df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]= df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# 1   327       55   4500000.0   58853106.0      731    104.0
# 2  1745       55  18000000.0  538375067.0     1540    124.0
# 3  2246       55   3500000.0   83453539.0     1812     88.0
# 4   410       55   6000000.0   39846344.0     1777     98.0

# %%
df.sort_values(by=['gross'], ascending=False).head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0

# %%
df_numerized.corr().head()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
#
#              votes  director    writer      star   country    budget  \
# name      0.013088  0.009079  0.009081  0.006472 -0.010737  0.023970
# rating    0.033225  0.019483 -0.005921  0.013405  0.081244 -0.176002
# genre    -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.356564
# year      0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.329321
# released  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.014683
#
#              gross   company   runtime
# name      0.005533  0.009211  0.010392
# rating   -0.107339 -0.032943  0.062145
# ...

# %%
correlation_mat=df_numerized.corr()

corr_pairs=correlation_mat.unstack()
corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.008069
#          genre       0.016355
#          year        0.011453
#          released   -0.011311
#                        ...
# runtime  country    -0.078412
#          budget      0.320447
#          gross       0.245216
#          company     0.034402
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()

sorted_pairs
# Out:
# genre    budget    -0.356564
# budget   genre     -0.356564
# gross    genre     -0.235650
# genre    gross     -0.235650
# rating   budget    -0.176002
#                       ...
# budget   budget     1.000000
# country  country    1.000000
# gross    gross      1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
high_corr= sorted_pairs[(sorted_pairs) >0.5]

high_corr.head()

#votes and budget has the highest correlation to gross earnings
# Out:
# votes     gross       0.630757
# gross     votes       0.630757
# budget    gross       0.740395
# gross     budget      0.740395
# released  released    1.000000
# dtype: float64
